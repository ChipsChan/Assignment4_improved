# %% [markdown]
# # Create O.Henry Text Corpus

# %% [markdown]
# First, I will install the 'pandas' and 'spacy' libraries, which are essential for the operations we intend to perform in this script.

# %%
# Install pandas and spacy
# !pip install pandas spacy
# Out:
# Requirement already satisfied: pandas in d:\anaconda\app\lib\site-packages (1.5.3)
# Requirement already satisfied: spacy in d:\anaconda\app\lib\site-packages (3.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in d:\anaconda\app\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda\app\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in d:\anaconda\app\lib\site-packages (from pandas) (1.24.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in d:\anaconda\app\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in d:\anaconda\app\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in d:\anaconda\app\lib\site-packages (from spacy) (1.0.7)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in d:\anaconda\app\lib\site-packages (from spacy) (2.0.6)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in d:\anaconda\app\lib\site-packages (from spacy) (3.0.6)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in d:\anaconda\app\lib\site-packages (from spacy) (8.1.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in d:\anaconda\app\lib\site-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in d:\anaconda\app\lib\site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in d:\anaconda\app\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in d:\anaconda\app\lib\site-packages (from spacy) (0.4.2)
# Requirement already satisfied: pathy>=0.10.0 in d:\anaconda\app\lib\site-packages (from spacy) (0.10.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in d:\anaconda\app\lib\site-packages (from spacy) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in d:\anaconda\app\lib\site-packages (from spacy) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in d:\anaconda\app\lib\site-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in d:\anaconda\app\lib\site-packages (from spacy) (1.10.12)
# Requirement already satisfied: jinja2 in d:\anaconda\app\lib\site-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in d:\anaconda\app\lib\site-packages (from spacy) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda\app\lib\site-packages (from spacy) (23.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in d:\anaconda\app\lib\site-packages (from spacy) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in d:\anaconda\app\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.7.1)
# Requirement already satisfied: six>=1.5 in d:\anaconda\app\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda\app\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda\app\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda\app\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\app\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in d:\anaconda\app\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in d:\anaconda\app\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.1.3)
# Requirement already satisfied: colorama in d:\anaconda\app\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in d:\anaconda\app\lib\site-packages (from typer<0.8.0,>=0.3.0->spacy) (8.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\anaconda\app\lib\site-packages (from jinja2->spacy) (2.1.1)

# %%
# Download English language model
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.5.0/en_core_web_sm-3.5.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#       --------------------------------------- 0.3/12.8 MB 6.1 MB/s eta 0:00:03
#      -- ------------------------------------- 0.7/12.8 MB 7.4 MB/s eta 0:00:02
#      -- ------------------------------------- 0.9/12.8 MB 7.5 MB/s eta 0:00:02
#      --- ------------------------------------ 1.2/12.8 MB 6.3 MB/s eta 0:00:02
#      ---- ----------------------------------- 1.5/12.8 MB 6.3 MB/s eta 0:00:02
#      ----- ---------------------------------- 1.7/12.8 MB 6.5 MB/s eta 0:00:02
#      ------ --------------------------------- 2.0/12.8 MB 6.4 MB/s eta 0:00:02
#      ------- -------------------------------- 2.3/12.8 MB 6.4 MB/s eta 0:00:02
#      -------- ------------------------------- 2.7/12.8 MB 6.5 MB/s eta 0:00:02
#      --------- ------------------------------ 3.0/12.8 MB 6.5 MB/s eta 0:00:02
#      ---------- ----------------------------- 3.3/12.8 MB 6.6 MB/s eta 0:00:02
#      ----------- ---------------------------- 3.6/12.8 MB 6.6 MB/s eta 0:00:02
#      ------------ --------------------------- 4.0/12.8 MB 6.8 MB/s eta 0:00:02
#      ------------- -------------------------- 4.4/12.8 MB 7.1 MB/s eta 0:00:02
#      -------------- ------------------------- 4.6/12.8 MB 6.7 MB/s eta 0:00:02
#      --------------- ------------------------ 5.1/12.8 MB 6.9 MB/s eta 0:00:02
#      ----------------- ---------------------- 5.6/12.8 MB 7.3 MB/s eta 0:00:01
#      ------------------ --------------------- 6.0/12.8 MB 7.2 MB/s eta 0:00:01
#      -------------------- ------------------- 6.6/12.8 MB 7.6 MB/s eta 0:00:01
#      ---------------------- ----------------- 7.1/12.8 MB 7.8 MB/s eta 0:00:01
#      ----------------------- ---------------- 7.6/12.8 MB 8.0 MB/s eta 0:00:01
#      -------------------------- ------------- 8.4/12.8 MB 8.2 MB/s eta 0:00:01
#      --------------------------- ------------ 8.8/12.8 MB 8.4 MB/s eta 0:00:01
#      ----------------------------- ---------- 9.3/12.8 MB 8.5 MB/s eta 0:00:01
#      ------------------------------ --------- 9.9/12.8 MB 8.6 MB/s eta 0:00:01
#      --------------------------------- ------ 10.6/12.8 MB 9.0 MB/s eta 0:00:01
#      ---------------------------------- ----- 11.1/12.8 MB 9.1 MB/s eta 0:00:01
#      ------------------------------------ --- 11.6/12.8 MB 9.6 MB/s eta 0:00:01
#      ------------------------------------- - 12.4/12.8 MB 10.4 MB/s eta 0:00:01
#      --------------------------------------  12.8/12.8 MB 10.4 MB/s eta 0:00:01
#      --------------------------------------- 12.8/12.8 MB 10.2 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in d:\anaconda\app\lib\site-packages (from en-core-web-sm==3.5.0) (3.5.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in d:\anaconda\app\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in d:\anaconda\app\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in d:\anaconda\app\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.0.7)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in d:\anaconda\app\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.6)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in d:\anaconda\app\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.6)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in d:\anaconda\app\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (8.1.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in d:\anaconda\app\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in d:\anaconda\app\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in d:\anaconda\app\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.10)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in d:\anaconda\app\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.4.2)
# Requirement already satisfied: pathy>=0.10.0 in d:\anaconda\app\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.10.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in d:\anaconda\app\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in d:\anaconda\app\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (4.65.0)
# Requirement already satisfied: numpy>=1.15.0 in d:\anaconda\app\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.24.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in d:\anaconda\app\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in d:\anaconda\app\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.10.12)
# Requirement already satisfied: jinja2 in d:\anaconda\app\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.1.2)
# Requirement already satisfied: setuptools in d:\anaconda\app\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda\app\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (23.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in d:\anaconda\app\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in d:\anaconda\app\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda\app\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda\app\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda\app\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\app\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in d:\anaconda\app\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in d:\anaconda\app\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.1.3)
# Requirement already satisfied: colorama in d:\anaconda\app\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in d:\anaconda\app\lib\site-packages (from typer<0.8.0,>=0.3.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (8.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\anaconda\app\lib\site-packages (from jinja2->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.1.1)
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %% [markdown]
# I will read all text files from a specified folder.

# %%
import os
import pandas as pd

# Set the folder path where text files are stored
folder_path = './text'

# Initialize an empty list to store individual dataframes
dataframes = []

# Loop through each file in the folder
for filename in os.listdir(folder_path):
    # Check if the file is a text file
    if filename.endswith('.txt'):
        # Create the full path to the file
        file_path = os.path.join(folder_path, filename)
        # Open the file
        with open(file_path, 'r', encoding='utf-8') as file:
            # Read the content of the file
            text = file.read()

# %% [markdown]
# To ensure I only capture the essential text, I will remove any unnecessary copyright information. Furthermore, to avoid any copyright infringement issues, we have carefully reviewed and adhered to Project Gutenberg's guidelines.

# %%
# Remove copyright information and introductory content from text files
start_text = text.find("*** START OF THIS PROJECT GUTENBERG EBOOK")
end_text = text.find("*** END OF THIS PROJECT GUTENBERG EBOOK")
text = text[start_text:end_text] if start_text > -1 and end_text > -1 else text

# %%
# Clean up line breaks and carriage returns in text
text = text.replace('\n', ' ').replace('\r', '')

# %% [markdown]
# # Tokenization

# %% [markdown]
# From this section, I will begin the process of data annotation using the spaCy library. spaCy is a powerful and efficient tool for natural language processing, which allows us to perform tasks such as tokenization, lemmatization, part-of-speech tagging, and named entity recognition. I'll apply these techniques to our text data to extract meaningful linguistic features.

# %%
import spacy

# %%
# Load English language model
nlp = spacy.load('en_core_web_sm')

# %%
# Process the text with Spacy
doc = nlp(text)

# %%
# Generate a list of tokenization
tokens = [token.text for token in doc]
print("Tokens:", tokens)
# Out:
# Tokens: ['\ufeffThe', 'Project', 'Gutenberg', 'eBook', 'of', 'Whirligigs', '     ', 'This', 'ebook', 'is', 'for', 'the', 'use', 'of', 'anyone', 'anywhere', 'in', 'the', 'United', 'States', 'and', 'most', 'other', 'parts', 'of', 'the', 'world', 'at', 'no', 'cost', 'and', 'with', 'almost', 'no', 'restrictions', 'whatsoever', '.', 'You', 'may', 'copy', 'it', ',', 'give', 'it', 'away', 'or', 're', '-', 'use', 'it', 'under', 'the', 'terms', 'of', 'the', 'Project', 'Gutenberg', 'License', 'included', 'with', 'this', 'ebook', 'or', 'online', 'at', 'www.gutenberg.org', '.', 'If', 'you', 'are', 'not', 'located', 'in', 'the', 'United', 'States', ',', 'you', 'will', 'have', 'to', 'check', 'the', 'laws', 'of', 'the', 'country', 'where', 'you', 'are', 'located', 'before', 'using', 'this', 'eBook', '.', ' ', 'Title', ':', 'Whirligigs', '  ', 'Author', ':', 'O.', 'Henry', ' ', 'Release', 'date', ':', 'January', '1', ',', '1999', '[', 'eBook', '#', '1595', ']', '                ', 'Most', 'recently', 'updated', ':', 'June', '28', ',', '2023', ' ', 'Language', ':', 'English', '   ', '*', '*', '*', 'START', 'OF', 'THE', 'PROJECT', 'GUTENBERG', 'EBOOK', 'WHIRLIGIGS', '*', '*', '*', '   ', 'Whirligigs', ' ', 'by', 'O.', 'Henry', '  ', 'Contents', '  ', 'CHAPTER', 'I', 'THE', 'WORLD', 'AND', 'THE', 'DOOR', ' ', 'CHAPTER', 'II', 'THE', 'THEORY', 'AND', 'THE', 'HOUND', ' ', 'CHAPTER', 'III', 'THE', 'HYPOTHESES', 'OF', 'FAILURE', ' ', 'CHAPTER', 'IV', 'CALLOWAY', '’S', 'CODE', ' ', 'CHAPTER', 'V', 'A', 'MATTER', 'OF', 'MEAN', 'ELEVATION', ' ', 'CHAPTER', 'VI', '“', 'GIRL', '”', ' ', 'CHAPTER', 'VII', 'SOCIOLOGY', 'IN', 'SERGE', 'AND', 'STRAW', ' ', 'CHAPTER', 'VIII', 'THE', 'RANSOM', 'OF', 'RED', 'CHIEF', ' ', 'CHAPTER', 'IX', 'THE', 'MARRY', 'MONTH', 'OF', 'MAY', ' ', 'CHAPTER', 'X', 'A', 'TECHNICAL', 'ERROR', ' ', 'CHAPTER', 'XI', 'SUITE', 'HOMES', 'AND', 'THEIR', 'ROMANCE', ' ', 'CHAPTER', 'XII', 'THE', 'WHIRLIGIG', 'OF', 'LIFE', ' ', 'CHAPTER', 'XIII', 'A', 'SACRIFICE', 'HIT', ' ', 'CHAPTER', 'XIV', 'THE', 'ROADS', 'WE', 'TAKE', ' ', 'CHAPTER', 'XV', 'A', 'BLACKJACK', 'BARGAINER', ' ', 'CHAPTER', 'XVI', 'THE', 'SONG', 'AND', 'THE', 'SERGEANT', ' ', 'CHAPTER', 'XVII', 'ONE', 'DOLLAR', '’S', 'WORTH', ' ', 'CHAPTER', 'XVIII', 'A', 'NEWSPAPER', 'STORY', ' ', 'CHAPTER', 'XIX', 'TOMMY', '’S', 'BURGLAR', ' ', 'CHAPTER', 'XX', 'A', 'CHAPARRAL', 'CHRISTMAS', 'GIFT', ' ', 'CHAPTER', 'XXI', 'A', 'LITTLE', 'LOCAL', 'COLOUR', ' ', 'CHAPTER', 'XXII', 'GEORGIA', '’S', 'RULING', ' ', 'CHAPTER', 'XXIII', 'BLIND', 'MAN', '’S', 'HOLIDAY', ' ', 'CHAPTER', 'XXIV', 'MADAME', 'BO', '-', 'PEEP', ',', 'OF', 'THE', 'RANCHES', '    ', 'I', 'THE', 'WORLD', 'AND', 'THE', 'DOOR', '  ', 'A', 'favourite', 'dodge', 'to', 'get', 'your', 'story', 'read', 'by', 'the', 'public', 'is', 'to', 'assert', 'that', 'it', 'is', 'true', ',', 'and', 'then', 'add', 'that', 'Truth', 'is', 'stranger', 'than', 'Fiction', '.', 'I', 'do', 'not', 'know', 'if', 'the', 'yarn', 'I', 'am', 'anxious', 'for', 'you', 'to', 'read', 'is', 'true', ';', 'but', 'the', 'Spanish', 'purser', 'of', 'the', 'fruit', 'steamer', '_', 'El', 'Carrero', '_', 'swore', 'to', 'me', 'by', 'the', 'shrine', 'of', 'Santa', 'Guadalupe', 'that', 'he', 'had', 'the', 'facts', 'from', 'the', 'U.', 'S.', 'vice', '-', 'consul', 'at', 'La', 'Paz', '—', 'a', 'person', 'who', 'could', 'not', 'possibly', 'have', 'been', 'cognizant', 'of', 'half', 'of', 'them', '.', ' ', 'As', 'for', 'the', 'adage', 'quoted', 'above', ',', 'I', 'take', 'pleasure', 'in', 'puncturing', 'it', 'by', 'affirming', 'that', 'I', 'read', 'in', 'a', 'purely', 'fictional', 'story', 'the', 'other', 'day', 'the', 'line', ':', '“', '‘', 'Be', 'it', 'so', ',', '’', 'said', 'the', 'policeman', '.', '”', 'Nothing', 'so', 'strange', 'has', 'yet', 'cropped', 'out', 'in', 'Truth', '.', ' ', 'When', 'H.', 'Ferguson', 'Hedges', ',', 'millionaire', 'promoter', ',', 'investor', 'and', 'man', '-', 'about', '-', 'New', '-', 'York', ',', 'turned', 'his', 'thoughts', 'upon', 'matters' ...

# %% [markdown]
# # Lemmatization

# %%
# Generate a list of lemmatization
lemmas = [token.lemma_ for token in doc]
print("Lemmas:", lemmas)
# Out:
# Lemmas: ['\ufeffthe', 'Project', 'Gutenberg', 'eBook', 'of', 'Whirligigs', '     ', 'this', 'ebook', 'be', 'for', 'the', 'use', 'of', 'anyone', 'anywhere', 'in', 'the', 'United', 'States', 'and', 'most', 'other', 'part', 'of', 'the', 'world', 'at', 'no', 'cost', 'and', 'with', 'almost', 'no', 'restriction', 'whatsoever', '.', 'you', 'may', 'copy', 'it', ',', 'give', 'it', 'away', 'or', 're', '-', 'use', 'it', 'under', 'the', 'term', 'of', 'the', 'Project', 'Gutenberg', 'License', 'include', 'with', 'this', 'ebook', 'or', 'online', 'at', 'www.gutenberg.org', '.', 'if', 'you', 'be', 'not', 'locate', 'in', 'the', 'United', 'States', ',', 'you', 'will', 'have', 'to', 'check', 'the', 'law', 'of', 'the', 'country', 'where', 'you', 'be', 'locate', 'before', 'use', 'this', 'eBook', '.', ' ', 'title', ':', 'Whirligigs', '  ', 'author', ':', 'O.', 'Henry', ' ', 'Release', 'date', ':', 'January', '1', ',', '1999', '[', 'ebook', '#', '1595', ']', '                ', 'most', 'recently', 'update', ':', 'June', '28', ',', '2023', ' ', 'language', ':', 'English', '   ', '*', '*', '*', 'start', 'of', 'the', 'PROJECT', 'GUTENBERG', 'EBOOK', 'WHIRLIGIGS', '*', '*', '*', '   ', 'whirligig', ' ', 'by', 'O.', 'Henry', '  ', 'Contents', '  ', 'chapter', 'I', 'the', 'WORLD', 'and', 'the', 'DOOR', ' ', 'chapter', 'II', 'the', 'theory', 'and', 'the', 'HOUND', ' ', 'CHAPTER', 'III', 'the', 'hypothesis', 'of', 'FAILURE', ' ', 'CHAPTER', 'IV', 'CALLOWAY', '’S', 'code', ' ', 'chapter', 'v', 'a', 'matter', 'of', 'MEAN', 'elevation', ' ', 'CHAPTER', 'VI', '"', 'GIRL', '"', ' ', 'chapter', 'VII', 'SOCIOLOGY', 'in', 'serge', 'and', 'straw', ' ', 'chapter', 'VIII', 'the', 'RANSOM', 'of', 'RED', 'CHIEF', ' ', 'CHAPTER', 'IX', 'the', 'MARRY', 'MONTH', 'of', 'MAY', ' ', 'CHAPTER', 'X', 'a', 'TECHNICAL', 'error', ' ', 'chapter', 'XI', 'SUITE', 'homes', 'and', 'their', 'romance', ' ', 'chapter', 'XII', 'the', 'WHIRLIGIG', 'of', 'life', ' ', 'chapter', 'xiii', 'a', 'sacrifice', 'hit', ' ', 'chapter', 'XIV', 'the', 'ROADS', 'we', 'take', ' ', 'chapter', 'XV', 'a', 'BLACKJACK', 'BARGAINER', ' ', 'CHAPTER', 'XVI', 'the', 'SONG', 'and', 'the', 'SERGEANT', ' ', 'chapter', 'XVII', 'one', 'dollar', '’s', 'worth', ' ', 'chapter', 'XVIII', 'a', 'newspaper', 'STORY', ' ', 'CHAPTER', 'XIX', 'TOMMY', '’S', 'BURGLAR', ' ', 'chapter', 'XX', 'a', 'CHAPARRAL', 'CHRISTMAS', 'GIFT', ' ', 'chapter', 'XXI', 'a', 'LITTLE', 'local', 'COLOUR', ' ', 'CHAPTER', 'XXII', 'GEORGIA', '’s', 'ruling', ' ', 'chapter', 'XXIII', 'BLIND', 'MAN', '’s', 'HOLIDAY', ' ', 'chapter', 'XXIV', 'MADAME', 'BO', '-', 'PEEP', ',', 'of', 'the', 'RANCHES', '    ', 'I', 'the', 'WORLD', 'and', 'the', 'door', '  ', 'a', 'favourite', 'dodge', 'to', 'get', 'your', 'story', 'read', 'by', 'the', 'public', 'be', 'to', 'assert', 'that', 'it', 'be', 'true', ',', 'and', 'then', 'add', 'that', 'truth', 'be', 'strange', 'than', 'Fiction', '.', 'I', 'do', 'not', 'know', 'if', 'the', 'yarn', 'I', 'be', 'anxious', 'for', 'you', 'to', 'read', 'be', 'true', ';', 'but', 'the', 'spanish', 'purser', 'of', 'the', 'fruit', 'steamer', '_', 'El', 'Carrero', '_', 'swear', 'to', 'I', 'by', 'the', 'shrine', 'of', 'Santa', 'Guadalupe', 'that', 'he', 'have', 'the', 'fact', 'from', 'the', 'U.', 'S.', 'vice', '-', 'consul', 'at', 'La', 'Paz', '—', 'a', 'person', 'who', 'could', 'not', 'possibly', 'have', 'be', 'cognizant', 'of', 'half', 'of', 'they', '.', ' ', 'as', 'for', 'the', 'adage', 'quote', 'above', ',', 'I', 'take', 'pleasure', 'in', 'puncture', 'it', 'by', 'affirm', 'that', 'I', 'read', 'in', 'a', 'purely', 'fictional', 'story', 'the', 'other', 'day', 'the', 'line', ':', '"', "'", 'be', 'it', 'so', ',', "'", 'say', 'the', 'policeman', '.', '"', 'nothing', 'so', 'strange', 'have', 'yet', 'crop', 'out', 'in', 'Truth', '.', ' ', 'when', 'H.', 'Ferguson', 'Hedges', ',', 'millionaire', 'promoter', ',', 'investor', 'and', 'man', '-', 'about', '-', 'New', '-', 'York', ',', 'turn', 'his', 'thought', 'upon', 'matter', 'convivial', ',', 'and', 'wo ...

# %% [markdown]
# # POS-tagging

# %%
# Generate a list of words with their POS
pos_tags = [(token.text, token.pos_) for token in doc]
print("POS tags:", pos_tags)
# Out:
# POS tags: [('\ufeffThe', 'NOUN'), ('Project', 'PROPN'), ('Gutenberg', 'PROPN'), ('eBook', 'PROPN'), ('of', 'ADP'), ('Whirligigs', 'PROPN'), ('     ', 'SPACE'), ('This', 'DET'), ('ebook', 'NOUN'), ('is', 'AUX'), ('for', 'ADP'), ('the', 'DET'), ('use', 'NOUN'), ('of', 'ADP'), ('anyone', 'PRON'), ('anywhere', 'ADV'), ('in', 'ADP'), ('the', 'DET'), ('United', 'PROPN'), ('States', 'PROPN'), ('and', 'CCONJ'), ('most', 'ADJ'), ('other', 'ADJ'), ('parts', 'NOUN'), ('of', 'ADP'), ('the', 'DET'), ('world', 'NOUN'), ('at', 'ADP'), ('no', 'DET'), ('cost', 'NOUN'), ('and', 'CCONJ'), ('with', 'ADP'), ('almost', 'ADV'), ('no', 'PRON'), ('restrictions', 'NOUN'), ('whatsoever', 'ADV'), ('.', 'PUNCT'), ('You', 'PRON'), ('may', 'AUX'), ('copy', 'VERB'), ('it', 'PRON'), (',', 'PUNCT'), ('give', 'VERB'), ('it', 'PRON'), ('away', 'ADV'), ('or', 'CCONJ'), ('re', 'VERB'), ('-', 'VERB'), ('use', 'VERB'), ('it', 'PRON'), ('under', 'ADP'), ('the', 'DET'), ('terms', 'NOUN'), ('of', 'ADP'), ('the', 'DET'), ('Project', 'PROPN'), ('Gutenberg', 'PROPN'), ('License', 'PROPN'), ('included', 'VERB'), ('with', 'ADP'), ('this', 'DET'), ('ebook', 'NOUN'), ('or', 'CCONJ'), ('online', 'NOUN'), ('at', 'ADP'), ('www.gutenberg.org', 'NOUN'), ('.', 'PUNCT'), ('If', 'SCONJ'), ('you', 'PRON'), ('are', 'AUX'), ('not', 'PART'), ('located', 'VERB'), ('in', 'ADP'), ('the', 'DET'), ('United', 'PROPN'), ('States', 'PROPN'), (',', 'PUNCT'), ('you', 'PRON'), ('will', 'AUX'), ('have', 'VERB'), ('to', 'PART'), ('check', 'VERB'), ('the', 'DET'), ('laws', 'NOUN'), ('of', 'ADP'), ('the', 'DET'), ('country', 'NOUN'), ('where', 'SCONJ'), ('you', 'PRON'), ('are', 'AUX'), ('located', 'VERB'), ('before', 'ADP'), ('using', 'VERB'), ('this', 'DET'), ('eBook', 'PROPN'), ('.', 'PUNCT'), (' ', 'SPACE'), ('Title', 'NOUN'), (':', 'PUNCT'), ('Whirligigs', 'PROPN'), ('  ', 'SPACE'), ('Author', 'NOUN'), (':', 'PUNCT'), ('O.', 'PROPN'), ('Henry', 'PROPN'), (' ', 'SPACE'), ('Release', 'PROPN'), ('date', 'NOUN'), (':', 'PUNCT'), ('January', 'PROPN'), ('1', 'NUM'), (',', 'PUNCT'), ('1999', 'NUM'), ('[', 'X'), ('eBook', 'VERB'), ('#', 'SYM'), ('1595', 'NUM'), (']', 'PUNCT'), ('                ', 'SPACE'), ('Most', 'ADV'), ('recently', 'ADV'), ('updated', 'VERB'), (':', 'PUNCT'), ('June', 'PROPN'), ('28', 'NUM'), (',', 'PUNCT'), ('2023', 'NUM'), (' ', 'SPACE'), ('Language', 'NOUN'), (':', 'PUNCT'), ('English', 'PROPN'), ('   ', 'SPACE'), ('*', 'PUNCT'), ('*', 'PUNCT'), ('*', 'ADJ'), ('START', 'NOUN'), ('OF', 'ADP'), ('THE', 'DET'), ('PROJECT', 'PROPN'), ('GUTENBERG', 'PROPN'), ('EBOOK', 'VERB'), ('WHIRLIGIGS', 'PROPN'), ('*', 'PUNCT'), ('*', 'PUNCT'), ('*', 'PUNCT'), ('   ', 'SPACE'), ('Whirligigs', 'NOUN'), (' ', 'SPACE'), ('by', 'ADP'), ('O.', 'PROPN'), ('Henry', 'PROPN'), ('  ', 'SPACE'), ('Contents', 'PROPN'), ('  ', 'SPACE'), ('CHAPTER', 'NOUN'), ('I', 'PRON'), ('THE', 'DET'), ('WORLD', 'PROPN'), ('AND', 'CCONJ'), ('THE', 'DET'), ('DOOR', 'PROPN'), (' ', 'SPACE'), ('CHAPTER', 'NOUN'), ('II', 'PROPN'), ('THE', 'DET'), ('THEORY', 'NOUN'), ('AND', 'CCONJ'), ('THE', 'DET'), ('HOUND', 'PROPN'), (' ', 'SPACE'), ('CHAPTER', 'PROPN'), ('III', 'PROPN'), ('THE', 'DET'), ('HYPOTHESES', 'NOUN'), ('OF', 'ADP'), ('FAILURE', 'PROPN'), (' ', 'SPACE'), ('CHAPTER', 'PROPN'), ('IV', 'PROPN'), ('CALLOWAY', 'PROPN'), ('’S', 'PROPN'), ('CODE', 'NOUN'), (' ', 'SPACE'), ('CHAPTER', 'NOUN'), ('V', 'NOUN'), ('A', 'NOUN'), ('MATTER', 'NOUN'), ('OF', 'ADP'), ('MEAN', 'PROPN'), ('ELEVATION', 'NOUN'), (' ', 'SPACE'), ('CHAPTER', 'PROPN'), ('VI', 'PROPN'), ('“', 'PUNCT'), ('GIRL', 'PROPN'), ('”', 'PUNCT'), (' ', 'SPACE'), ('CHAPTER', 'NOUN'), ('VII', 'PROPN'), ('SOCIOLOGY', 'VERB'), ('IN', 'ADP'), ('SERGE', 'NOUN'), ('AND', 'CCONJ'), ('STRAW', 'NOUN'), (' ', 'SPACE'), ('CHAPTER', 'NOUN'), ('VIII', 'PROPN'), ('THE', 'DET'), ('RANSOM', 'PROPN'), ('OF', 'ADP'), ('RED', 'PROPN'), ('CHIEF', 'PROPN'), (' ', 'SPACE'), ('CHAPTER', 'PROPN'), ('IX', 'PROPN'), ('THE', 'DET'), ('MARRY', 'PROPN'), ('MONTH', 'PROPN'), ('OF', 'ADP'), ('MAY', 'PR ...

# %% [markdown]
# # Create a csv file

# %%
# Create a DataFrame for the current document
df = pd.DataFrame({
    'Filename': [filename],
    'Document': [text],
    'Tokens': [tokens],
    'Lemmas': [lemmas],
    'POS': [pos_tags]
})

# Append the DataFrame to the list
dataframes.append(df)

# %%
# Concatenate all dataframes into one
corpus_df = pd.concat(dataframes, ignore_index=True)

# Save the DataFrame to a CSV file
corpus_df.to_csv("corpus.csv", index=False)

# Print the first few rows of the DataFrame
print(corpus_df.head())
# Out:
#          Filename                                           Document  \
# 0  Whirligigs.txt  ﻿The Project Gutenberg eBook of Whirligigs    ...
#
#                                               Tokens  \
# 0  [﻿The, Project, Gutenberg, eBook, of, Whirligi...
#
#                                               Lemmas  \
# 0  [﻿the, Project, Gutenberg, eBook, of, Whirligi...
#
#                                                  POS
# 0  [(﻿The, NOUN), (Project, PROPN), (Gutenberg, P...
